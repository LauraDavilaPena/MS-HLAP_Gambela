# %% [markdown]
# # Creating input GeoJson for Kule Refugee Camp
#
# This notebook is intended to generate the input data for the **Kule** refugee camp to subsequently be able to apply our model. We use data from OpenStreetMap and identify the current buildings, roads, and both potential and existing healthcare facilities.
# The goal is to:
# - Identify **demand points** using building centroids.
# - Generate **candidate sites** for new **Health Centers (HCs)** and **Health Posts (HPs)** near existing roads.
# - Situate **existing facilities** based on coordinates send by CUAMM.
# - Plot the results with categorized elements.
# - Create a **GeoJson** file with all the above information.

# %% [markdown]
# ### 1. Import Required Libraries

# %%
import osmnx as ox
import geopandas as gpd
import numpy as np
import random
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
import json
from shapely.geometry import Point, MultiPoint
from sklearn.cluster import KMeans

# %% [markdown]
# ### 2. Load Spatial Data from OpenStreetMap
#
# We extract:
# - **Area boundary** (`area`)
# - **Buildings** (`buildings`)
# - **Roads** (`roads`)

# %%
# Specify the location name
place_name = "Kule, Ethiopia"

# Get area boundary as a GeoDataFrame
area = ox.geocode_to_gdf(place_name)

# Extract buildings from OSM
buildings = ox.features_from_place(place_name, tags={'building': 'yes'})

# %%
# Get all road-related amenities in the location
road_tags = {"highway": True}
roads = ox.features_from_place(place_name, road_tags)

# Extract unique values
unique_highways = roads["highway"].dropna().unique()

#  Print results
print("Unique highway types:", unique_highways)
# Out:
# Unique highway types: ['tertiary' 'track' 'residential' 'path' 'service' 'unclassified']

# %%
# Plot all of them
roads.plot()
# Out:
# <Axes: >

# %%
# Filter relevant road-related features (by visually extracting them)
road_keywords = ['tertiary', 'track', 'residential', 'unclassified']
road_amenities = roads[roads["highway"].isin(road_keywords)]

# Plot the selected subset
road_amenities.plot()
# Out:
# <Axes: >

# %%
# Create subplots (1 row, 3 columns)
fig, axes = plt.subplots(1, 3, figsize=(15, 5))  # 3 side-by-side plots

# Plot each dataset separately
area.plot(ax=axes[0], color="lightgray", edgecolor="black")
axes[0].set_title("Area Boundary")

buildings.plot(ax=axes[1], color="blue", alpha=0.6, edgecolor="black")
axes[1].set_title("Buildings")

road_amenities.plot(ax=axes[2], color="green", alpha=0.6)
axes[2].set_title("Roads")

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Load Existing Health Facilities
#
# We have not been provided information about existing facilities at Kule refugee camp from CUAMM. However, we will consider the existing _clinics_ as per OSM as potential location for both HPs and HCs.
#
# - **Existing Health Center (HC)**: Provided coordinates for the HC
# - **Existing Health Posts (HPs)**: Provided coordinates for the HPs

# %%
# Existing clinics are also identified in OSM as a 'clinics'
clinics = ox.features_from_place(place_name, tags={'amenity': 'clinic'})

clinics.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### 4. Process Buildings: Compute Centroids & Filter Valid Demand Points
#
# 1. **Reproject buildings** to a projected CRS (EPSG:3395 - meters-based)
# 2. **Compute centroids** of buildings (which are currently recognize as polygons)
# 3. **Filter centroids** to exclude existing facilities

# %%
# Reproject buildings to EPSG:3395
buildings_projected = buildings.to_crs(epsg=3395)

# Compute centroids
buildings_projected["centroid"] = buildings_projected.geometry.centroid
centroid_coords = buildings_projected["centroid"].apply(lambda geom: (geom.x, geom.y))

# Combine existing health facilities
existing_facilities = MultiPoint([*clinics.geometry])

# Function to filter valid centroids
def filter_valid_centroids(centroid_coords, existing_facilities):
    return [Point(c) for c in centroid_coords if not existing_facilities.intersects(Point(c))]

# Get valid centroids
valid_centroids = filter_valid_centroids(centroid_coords, existing_facilities)

# %% [markdown]
# ### 5. Generate Demand Points using KMeans Clustering
#
# We consider the centroids of the 13,564 buildings and cluster them into 200 "population zones" (which will be our demand points)
# - **Clusters:** 200
# - **Method:** KMeans
# - **Goal:** Assign each demand point to a cluster

# %%
# Set seeds for reproducibility
random.seed(30)
np.random.seed(30)

# Perform KMeans clustering on valid centroids
kmeans = KMeans(n_clusters=200, random_state=30)
valid_centroids_coords = np.array([p.coords[0] for p in valid_centroids])
kmeans.fit(valid_centroids_coords)
# Out:
# KMeans(n_clusters=200, random_state=30)

# %% [markdown]
# ### 6. Generate Candidate Sites for New Facilities Near Roads
# We are already considering 6 "existing" sites for both HP and HC (then, our model will just decide which facility-type goes at that location). Hence, we will aim for 4 additional candidate sites of both HPs and HCs
#
# 1. **Reproject roads**
# 2. **Buffer roads** (100m) to find nearby spaces
# 3. **Avoid existing facilities**

# %%
# Reproject both roads and area to EPSG:3395
roads_projected = road_amenities.to_crs(epsg=3395)
area_projected = area.to_crs(epsg=3395)  # Ensure area is in the same CRS

# Clip roads within the area boundary
roads_clipped = gpd.clip(roads_projected, area_projected)

# Create buffer (100m around roads)
buffer_distance = 100
road_buffer = roads_clipped.buffer(buffer_distance)

# Extract candidate sites near roads
road_candidate_sites = [poly.representative_point() for poly in road_buffer if not existing_facilities.intersects(poly)]

# Shuffle candidate sites for randomness
random.shuffle(road_candidate_sites)

# Select 4 HPs and 4 HCs
new_hp_sites = road_candidate_sites[:5]
new_hc_sites = road_candidate_sites[5:10]

# %% [markdown]
# ### 7. Reproject Existing Facilities to Match EPSG:3395

# %%
existing_hcs_projected = clinics.to_crs(epsg=3395)
existing_hps_projected = clinics.to_crs(epsg=3395)

len(existing_hcs_projected)
# Out:
# 6

# %% [markdown]
# ### 8. Plot the Results with Custom Legend

# %%
# Create figure
fig, ax = plt.subplots(figsize=(10, 10))

# Plot buildings
buildings_projected.plot(ax=ax, color="lightblue", alpha=0.8, edgecolor="lightblue")

# Plot roads
roads_clipped.plot(ax=ax, color="green", alpha=0.5, linewidth=1)

# Plot demand points
ax.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], color="red", marker="o", s=15)

# Plot candidate HPs and HCs
for hp in new_hp_sites:
    ax.plot(hp.x, hp.y, '^', color='blue', alpha=0.3, markersize=8)  # Blue triangle
for hc in new_hc_sites:
    ax.plot(hc.x, hc.y, 's', color='black', alpha=0.3, markersize=8)  # Black square

# Plot existing HC
ax.plot(existing_hcs_projected.geometry.x, existing_hcs_projected.geometry.y, 's', color='black', markersize=8)

# Plot existing HPs
ax.plot(existing_hps_projected.geometry.x, existing_hps_projected.geometry.y, '^', color='blue', markersize=8)


# Plot the boundary of the area (outline only)
area_projected.plot(ax=ax, edgecolor="gray", alpha=0.3, linewidth=1, facecolor="none")

# Define legend elements
building_patch = mpatches.Patch(color="lightblue", alpha=0.8, label="Buildings")
road_patch = mlines.Line2D([], [], color='green', alpha=0.5, linewidth=1, label="Roads")
demand_patch = mlines.Line2D([], [], marker='o', color='w', markerfacecolor='red', markersize=10, label="Demand Points")
existing_hc_patch = mlines.Line2D([], [], marker='s', color='w', markerfacecolor='black', markersize=10, label="Existing HC")
candidate_hcs_patch = mlines.Line2D([], [], marker='s', color='w', markerfacecolor='black', alpha=0.3, markersize=10, label="Candidate HCs")
existing_hps_patch = mlines.Line2D([], [], marker='^', color='w', markerfacecolor='blue', markersize=10, label="Existing HPs")
candidate_hps_patch = mlines.Line2D([], [], marker='^', color='w', markerfacecolor='blue', alpha=0.3, markersize=10, label="Candidate HPs")

# Add legend
plt.legend(handles=[building_patch, road_patch, demand_patch, existing_hc_patch, candidate_hcs_patch, existing_hps_patch, candidate_hps_patch])
plt.title(f"Buildings, Demand Points, Existing Facilities, and Candidate Sites in {place_name}")

plt.savefig("kule7.png", dpi=300, bbox_inches="tight")

# Show plot
plt.show()

# %% [markdown]
# ### 9. Convert Data for GeoJSON Export
# This section builds on the previous analysis by:
# 1. Converting demand points, candidate facilities, and existing facilities to EPSG:4326
# 2. Structuring all data into a **GeoJSON format**
# 3. Exporting the data for further use

# %% [markdown]
# #### 9.1. Convert Demand Points (KMeans Centroids) to EPSG:4326
# - The demand points are already clustered (`kmeans.cluster_centers_`)
# - Convert them to **latitude/longitude**

# %%
# Convert demand points (KMeans centroids) to GeoDataFrame
gdf_demand = gpd.GeoDataFrame(
    geometry=[Point(x, y) for x, y in kmeans.cluster_centers_],
    crs="EPSG:3395"
).to_crs("EPSG:4326")

# Extract lat/lon coordinates
demand_centroids_latlon = gdf_demand.geometry.apply(lambda point: [point.x, point.y]).tolist()

# %% [markdown]
# #### 9.2. Convert Candidate HP and HC Locations to EPSG:4326
# - These points were previously selected near roads (`new_hp_sites` and `new_hc_sites`)
# - Convert them to **latitude/longitude**

# %%
# Convert HP candidates to GeoDataFrame
gdf_new_hp_sites = gpd.GeoDataFrame(geometry=new_hp_sites, crs="EPSG:3395").to_crs("EPSG:4326")

new_hp_sites_latlon = gdf_new_hp_sites.geometry.apply(lambda point: [point.x, point.y]).tolist()

# Convert HC candidates to GeoDataFrame
gdf_new_hc_sites = gpd.GeoDataFrame(geometry=new_hc_sites, crs="EPSG:3395").to_crs("EPSG:4326")

new_hc_sites_latlon = gdf_new_hc_sites.geometry.apply(lambda point: [point.x, point.y]).tolist()

# %%
existing_hps_projected.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x000001AF28AE6BD0>

# %% [markdown]
# ### 9.3. Convert Existing Facilities to EPSG:4326
# - The **"existing" health centers (HCs)**
# - The **"existing" health posts (HPs)**
# - Assign **custom names** for better identification

# %%
# Convert Existing HC (already in EPSG:3395, reproject it)
existing_hcs_projected = existing_hcs_projected.to_crs("EPSG:4326")
existing_hcs_latlon = [existing_hcs_projected.iloc[0].geometry.x, existing_hcs_projected.iloc[0].geometry.y]

# Convert Existing HPs
existing_hps_projected = existing_hps_projected.to_crs("EPSG:4326")
existing_hps_latlon = existing_hps_projected.geometry.apply(lambda point: [point.x, point.y]).tolist()

existing_facilities = []

# Convert HPs
for i, row in enumerate(existing_hps_projected.iterrows()):
    existing_facilities.append({
        "type": "HP",
        "name": f"HP_ExistingLocation{i+1}",
        "coords": row[1].geometry
    })

# Convert HCs
for i, row in enumerate(existing_hcs_projected.iterrows()):
    existing_facilities.append({
        "type": "HC",
        "name": f"HC_ExistingLocation{i+1}",
        "coords": row[1].geometry
    })

# Print result
for facility in existing_facilities:
    print(facility)
# Out:
# {'type': 'HP', 'name': 'HP_ExistingLocation1', 'coords': <POINT (34.252 8.286)>}
# {'type': 'HP', 'name': 'HP_ExistingLocation2', 'coords': <POINT (34.264 8.292)>}
# {'type': 'HP', 'name': 'HP_ExistingLocation3', 'coords': <POINT (34.239 8.303)>}
# {'type': 'HP', 'name': 'HP_ExistingLocation4', 'coords': <POINT (34.256 8.295)>}
# {'type': 'HP', 'name': 'HP_ExistingLocation5', 'coords': <POINT (34.254 8.296)>}
# {'type': 'HP', 'name': 'HP_ExistingLocation6', 'coords': <POINT (34.255 8.299)>}
# {'type': 'HC', 'name': 'HC_ExistingLocation1', 'coords': <POINT (34.252 8.286)>}
# {'type': 'HC', 'name': 'HC_ExistingLocation2', 'coords': <POINT (34.264 8.292)>}
# {'type': 'HC', 'name': 'HC_ExistingLocation3', 'coords': <POINT (34.239 8.303)>}
# {'type': 'HC', 'name': 'HC_ExistingLocation4', 'coords': <POINT (34.256 8.295)>}
# {'type': 'HC', 'name': 'HC_ExistingLocation5', 'coords': <POINT (34.254 8.296)>}
# {'type': 'HC', 'name': 'HC_ExistingLocation6', 'coords': <POINT (34.255 8.299)>}

# %% [markdown]
# ### 9.4. Generate GeoJSON Features
# We create a **GeoJSON structure** for:
# 1. Demand points
# 2. Candidate HP locations
# 3. Candidate HC locations
# 4. Existing facilities

# %%
# Initialize an empty list to store features
features = []

# Demand Points
for i, centroid in enumerate(demand_centroids_latlon):
    feature = {
        "type": "Feature",
        "properties": {
            "Name": f"Kule{i+1}", 
            "Camp": "Kule", 
            "type_f": "demand_point"
        },
        "geometry": {
            "type": "Point",
            "coordinates": centroid  # [Longitude, Latitude]
        }
    }
    features.append(feature)

# Candidate sites for HPs
for i, hp in enumerate(new_hp_sites_latlon):
    feature = {
        "type": "Feature",
        "properties": {
            "Name": f"HP_CandidateLocation{i+1}",
            "Camp": "Kule",
            "type_f": "HP"
        },
        "geometry": {
            "type": "Point",
            "coordinates": hp
        }
    }
    features.append(feature)

# Candidate sites for HCs
for i, hc in enumerate(new_hc_sites_latlon):
    feature = {
        "type": "Feature",
        "properties": {
            "Name": f"HC_CandidateLocation{i+1}",
            "Camp": "Kule",
            "type_f": "HC"
        },
        "geometry": {
            "type": "Point",
            "coordinates": hc
        }
    }
    features.append(feature)

# Existing Facilities (Custom Names)
for facility in existing_facilities:
    feature = {
        "type": "Feature",
        "properties": {
            "Name": facility["name"],
            "Camp": "Kule",
            "type_f": facility["type"]
        },
        "geometry": {
            "type": "Point",
            "coordinates": [facility['coords'].x, facility['coords'].y]  # Extract coordinates
        }
    }
    features.append(feature)

# %% [markdown]
# ### 9.5. Create Final GeoJSON Structure

# %%
features
# Out:
# [{'type': 'Feature',
#   'properties': {'Name': 'Kule1', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.2547860343514, 8.299924522443225]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule2', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25601727375978, 8.28407671680313]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule3', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.24549466742631, 8.304170443647301]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule4', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25933812819953, 8.293452001001844]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule5', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.23201748505849, 8.304557840103898]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule6', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.260906474851254, 8.29715700992317]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule7', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25742917101173, 8.286937662197001]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule8', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25066565744737, 8.30173167936554]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule9', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.2526449417701, 8.281198777824576]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule10', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.237707527228416, 8.303942014441146]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule11', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.253265207215854, 8.28675926490039]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule12', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.26251784024061, 8.29186894822352]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule13', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25278512489902, 8.296372180745795]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule14', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.24107108921254, 8.30322115084236]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule15', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.258988370511304, 8.290322921846444]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule16', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.255891148402185, 8.296175765444476]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule17', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25098373630209, 8.303293938109263]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule18', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.24832459006135, 8.300971101359988]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule19', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.22951486952717, 8.30438719571991]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule20', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25767735662269, 8.282533238157189]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule21', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.2554455066668, 8.302405282827761]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule22', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25376731542268, 8.300287441648885]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule23', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25404561825237, 8.283701618636256]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule24', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25585275055278, 8.281948195904626]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule25', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.245980995606885, 8.301493609343698]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule26', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.259132307099094, 8.296645763686696]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule27', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.2608240438208, 8.294782126234457]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule28', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.259037117705326, 8.286889549816827]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule29', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.253567835932294, 8.30384451893578]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule30', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25761625834535, 8.292312326055875]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule31', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.24851027693507, 8.304134804087283]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule32', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25196480469834, 8.28265565789537]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule33', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.250087621759114, 8.298703062373825]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule34', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.234652274461325, 8.304196545871442]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule35', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25490335969838, 8.285508525228947]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule36', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.261818287624635, 8.299546796069528]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule37', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.257406764670996, 8.294214800606174]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule38', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25402037654152, 8.295029801466628]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule39', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.252403139262505, 8.284522146870232]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule40', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.26040352416738, 8.289583061495707]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule41', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.26129202371938, 8.293089170839673]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule42', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.2444925808124, 8.303043222583106]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule43', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25699283340276, 8.285222741597448]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule44', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25786367975069, 8.291468177346655]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule45', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.257467600184285, 8.289550475846289]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule46', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.254479631971456, 8.302422817112225]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule47', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25862983434838, 8.295089640398462]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule48', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.26365075586805, 8.295286938361711]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule49', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.241437465306824, 8.304547585002364]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule50', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.251179531725725, 8.30113809457508]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule51', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.24657740444844, 8.30332084405599]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule52', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25874302317787, 8.28566383565059]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule53', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25613605878929, 8.280087531954514]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule54', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.261285470785644, 8.298893386724817]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule55', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.255936637129416, 8.28681545560195]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule56', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25217393120615, 8.302100599781213]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule57', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.26042630489997, 8.291397973497778]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule58', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25224458652681, 8.29922457695344]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule59', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.24412834322029, 8.304233031436068]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule60', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.259570365234644, 8.288004782217975]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule61', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25362732897517, 8.28212304056852]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule62', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25772932128151, 8.28471376800937]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule63', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.24768349016271, 8.301748061027848]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule64', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.26206084190984, 8.293782097866206]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule65', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.26157411184145, 8.290217672806147]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule66', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25822686609141, 8.289684555250966]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule67', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.242349236727335, 8.301807429245766]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule68', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.254061545317604, 8.2971119821481]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule69', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25723220730035, 8.28117916620773]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule70', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.23029778205167, 8.30351511914976]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule71', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25573830308201, 8.285866520260564]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule72', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.24816531099257, 8.302688669239469]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule73', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25444783022192, 8.303646416632022]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule74', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.2604713838315, 8.296422558375363]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule75', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.23925234587576, 8.3049279591577]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule76', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.26398002117533, 8.293129547374768]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule77', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25560940496173, 8.28283284867088]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule78', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25015353121489, 8.30423798794117]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule79', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25759317874051, 8.295413640242588]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule80', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.251959886532454, 8.303128292245463]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule81', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.261810742217456, 8.296185354540599]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule82', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.257699789370925, 8.286015990823639]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule83', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.24261518236366, 8.304237595027018]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule84', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.24352895111971, 8.301828727917608]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule85', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.253529037133276, 8.285792915824665]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule86', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.24514879665283, 8.301819967879425]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule87', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.24986067550895, 8.301359115008827]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule88', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25843828186474, 8.287392214605553]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule89', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25324716015262, 8.28458236657438]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule90', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25419494614059, 8.301415850991095]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule91', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.253400041685126, 8.299250417917346]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule92', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25983854999722, 8.292270433176018]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule93', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.256501022253545, 8.282365908328032]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule94', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.24882298468604, 8.282624376321372]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule95', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25199709083204, 8.300793451416753]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule96', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25318855130099, 8.283411203805663]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule97', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.26047911716272, 8.298475316916337]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule98', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.2598099551456, 8.29588094925232]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule99', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.254614884318094, 8.281811086721266]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule100', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25805657636125, 8.288707977223584]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule101', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25647907922433, 8.29421428489257]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule102', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25379656663331, 8.27969067340326]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule103', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.24702026261202, 8.300930264664888]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule104', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.256845263985596, 8.29313543399769]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule105', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25820817754831, 8.290553231558652]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule106', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.247574238179546, 8.303567983779159]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule107', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25303256670818, 8.302983519228697]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule108', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25528352474414, 8.28851716121285]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule109', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.22918841009916, 8.303459892462678]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule110', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.257078044088324, 8.284131266191597]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule111', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.23668434075525, 8.304448138113761]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule112', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.2384674097602, 8.305094674694294]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule113', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25278505485727, 8.282352870769657]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule114', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25869350309435, 8.292795854938959]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule115', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.24264747452499, 8.30297184782375]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule116', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.254453048204866, 8.284520743767132]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule117', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25545582484143, 8.284845412945353]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule118', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.256374685123596, 8.286533009805087]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule119', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.259856905264634, 8.288946951712306]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule120', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.26024180265848, 8.293117073361836]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule121', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.238617939213555, 8.303891197083463]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule122', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.24560075710471, 8.302831086781607]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule123', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.23392213471772, 8.304100997735155]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule124', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.258748978306166, 8.297324040636202]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule125', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25958159119973, 8.294927025598192]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule126', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25338782548233, 8.302151935440472]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule127', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.258452377324524, 8.284996038430572]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule128', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.261268696094625, 8.295538110945348]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule129', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.24083191370052, 8.302235063748098]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule130', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.254268215492196, 8.286514497523283]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule131', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.251083561105595, 8.30012868026901]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule132', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.23261404554746, 8.305160145574044]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule133', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25508186345394, 8.301052559402224]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule134', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25284472412386, 8.297732018571807]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule135', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25265857766176, 8.28558839644316]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule136', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25534251726365, 8.28139876911599]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule137', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.262481940929355, 8.298501798263318]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule138', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25806771445006, 8.29628734734891]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule139', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.24907078548774, 8.302714583933506]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule140', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.249028128579646, 8.301716622301726]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule141', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25844067497258, 8.294067353940015]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule142', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25747048300896, 8.290825868476029]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule143', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25236888546794, 8.299975887936194]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule144', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.255672377146176, 8.293647054074615]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule145', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.26099082417778, 8.292164732422128]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule146', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.2607576834277, 8.300350443329865]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule147', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.24911524462554, 8.299456719544743]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule148', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.24946991488358, 8.303597203566389]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule149', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.2519478736795, 8.281694516683206]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule150', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.2603101787102, 8.294167878879792]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule151', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.2619753848594, 8.29714474768225]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule152', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.254457224850036, 8.29421094208576]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule153', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.23573588855589, 8.304386786377119]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule154', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.24697149903507, 8.30450832246645]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule155', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25165547346827, 8.283383141167043]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule156', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.263716352937756, 8.292143267101109]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule157', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25510555290355, 8.283666717659607]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule158', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25260003304617, 8.301535871608685]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule159', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25234217372419, 8.303890846613497]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule160', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.254415365429416, 8.282819462936416]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule161', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25885350187599, 8.295925547539344]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule162', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.23939703134177, 8.303584300027715]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule163', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25781635494201, 8.29317818417997]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule164', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.26209580963902, 8.294866788556792]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule165', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25629917381128, 8.285174199957568]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule166', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25124410425365, 8.299244201100349]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule167', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.240619455804044, 8.304146092836877]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule168', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.26176873998831, 8.290929426630427]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule169', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.26042406619536, 8.290405629364521]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule170', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.24907543962971, 8.300562465991263]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule171', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25877691203476, 8.291696000636524]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule172', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.246915639784305, 8.302383295096314]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule173', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.254225536940105, 8.285453978000769]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule174', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25663950102229, 8.283284039506395]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule175', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.255421649155615, 8.29817293704676]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule176', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25836638257545, 8.286411452919111]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule177', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.26296392322633, 8.292824796878397]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule178', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25645503710119, 8.287287570006459]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule179', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25138039852488, 8.302286333949397]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule180', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.228248694441646, 8.303887674578219]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule181', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25986209672821, 8.297386762708811]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule182', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.257497357260696, 8.281800629757788]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule183', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.2568815782145, 8.286251486226147]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule184', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.2589877522892, 8.289103116201717]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule185', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.262980820312386, 8.294163453226739]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule186', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25966448900992, 8.290997100136064]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule187', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.23097511972778, 8.304543620325507]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule188', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25322502934431, 8.29549090995849]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule189', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.23777087004899, 8.305167262076454]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule190', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25712162111031, 8.288716526749006]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule191', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25123491913556, 8.30429508817629]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule192', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.257790011382085, 8.283496183397556]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule193', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25314545434419, 8.301047773255611]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule194', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.261314296843835, 8.289496508821156]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule195', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25340800551688, 8.281425832820307]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule196', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25065847821126, 8.298389432560084]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule197', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.261274285336164, 8.298007137892087]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule198', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.250183804485744, 8.302632693609837]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule199', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25533536888686, 8.303289410358715]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'Kule200', 'Camp': 'Kule', 'type_f': 'demand_point'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.259593873188074, 8.28987342002612]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'HP_CandidateLocation1',
#    'Camp': 'Kule',
#    'type_f': 'HP'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.247939036795785, 8.30096532051343]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'HP_CandidateLocation2',
#    'Camp': 'Kule',
#    'type_f': 'HP'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.255953703715655, 8.281736093346751]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'HP_CandidateLocation3',
#    'Camp': 'Kule',
#    'type_f': 'HP'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.258961534884065, 8.289720873033295]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'HP_CandidateLocation4',
#    'Camp': 'Kule',
#    'type_f': 'HP'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25949282400759, 8.295522198452527]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'HP_CandidateLocation5',
#    'Camp': 'Kule',
#    'type_f': 'HP'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.250708, 8.298771700006593]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'HC_CandidateLocation1',
#    'Camp': 'Kule',
#    'type_f': 'HC'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25843021330633, 8.284318242801199]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'HC_CandidateLocation2',
#    'Camp': 'Kule',
#    'type_f': 'HC'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25303141326393, 8.28589318742122]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'HC_CandidateLocation3',
#    'Camp': 'Kule',
#    'type_f': 'HC'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.26105685764413, 8.298991699314612]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'HC_CandidateLocation4',
#    'Camp': 'Kule',
#    'type_f': 'HC'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25638327942054, 8.283356375290735]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'HC_CandidateLocation5',
#    'Camp': 'Kule',
#    'type_f': 'HC'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.26248219354543, 8.294746036199056]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'HP_ExistingLocation1',
#    'Camp': 'Kule',
#    'type_f': 'HP'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.2520827, 8.286223999999999]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'HP_ExistingLocation2',
#    'Camp': 'Kule',
#    'type_f': 'HP'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.26358129999999, 8.292344499999999]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'HP_ExistingLocation3',
#    'Camp': 'Kule',
#    'type_f': 'HP'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.239114199999996, 8.303035399999999]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'HP_ExistingLocation4',
#    'Camp': 'Kule',
#    'type_f': 'HP'},
#   'geometry': {'type': 'Point', 'coordinates': [34.2556527, 8.2948076]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'HP_ExistingLocation5',
#    'Camp': 'Kule',
#    'type_f': 'HP'},
#   'geometry': {'type': 'Point', 'coordinates': [34.2537913, 8.2964399]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'HP_ExistingLocation6',
#    'Camp': 'Kule',
#    'type_f': 'HP'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25462009999999, 8.2989135]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'HC_ExistingLocation1',
#    'Camp': 'Kule',
#    'type_f': 'HC'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.2520827, 8.286223999999999]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'HC_ExistingLocation2',
#    'Camp': 'Kule',
#    'type_f': 'HC'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.26358129999999, 8.292344499999999]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'HC_ExistingLocation3',
#    'Camp': 'Kule',
#    'type_f': 'HC'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.239114199999996, 8.303035399999999]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'HC_ExistingLocation4',
#    'Camp': 'Kule',
#    'type_f': 'HC'},
#   'geometry': {'type': 'Point', 'coordinates': [34.2556527, 8.2948076]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'HC_ExistingLocation5',
#    'Camp': 'Kule',
#    'type_f': 'HC'},
#   'geometry': {'type': 'Point', 'coordinates': [34.2537913, 8.2964399]}},
#  {'type': 'Feature',
#   'properties': {'Name': 'HC_ExistingLocation6',
#    'Camp': 'Kule',
#    'type_f': 'HC'},
#   'geometry': {'type': 'Point',
#    'coordinates': [34.25462009999999, 8.2989135]}}]

# %%
geojson = {
    "type": "FeatureCollection",
    "name": "location_kule",
    "features": features
}

# Uncomment this block to save the GeoJSON file
with open("kule_baseline.geojson", "w") as f:
    json.dump(geojson, f)

print("GeoJSON file created: kule_baseline.geojson")
# Out:
# GeoJSON file created: kule_baseline.geojson

# %%
# Read the GeoJSON file
geojson_file = "kule_baseline.geojson"
gdf = gpd.read_file(geojson_file)

# Plot the GeoDataFrame, distinguishing by feature type
fig, ax = plt.subplots(figsize=(10, 10))

# Plot demand points
demand_points = gdf[gdf['type_f'] == 'demand_point']
demand_points.plot(ax=ax, marker='o', color='red', label='Demand Points', markersize=5)

# Plot HP candidates
hp_candidates = gdf[(gdf['type_f'] == 'HP') & (gdf['Name'].str.contains('Candidate'))]
hp_candidates.plot(ax=ax, marker='^', color='blue', alpha=0.5, label='HP Candidates', markersize=7)

# Plot HC candidates
hc_candidates = gdf[(gdf['type_f'] == 'HC') & (gdf['Name'].str.contains('Candidate'))]
hc_candidates.plot(ax=ax, marker='s', color='black', alpha=0.5, label='HC Candidates', markersize=7)

# Plot existing facilities (both HP and HC)
existing_hp = gdf[(gdf['type_f'] == 'HP') & (gdf['Name'].str.contains('Existing'))]
existing_hp.plot(ax=ax, marker='^', color='blue', label='Existing HPs', markersize=7)

existing_hc = gdf[(gdf['type_f'] == 'HC') & (gdf['Name'].str.contains('Existing'))]
existing_hc.plot(ax=ax, marker='s', color='black', label='Existing HCs', markersize=7)

# Customize plot
ax.set_title('Kule Location Map', fontsize=16)
ax.set_xlabel('Longitude', fontsize=12)
ax.set_ylabel('Latitude', fontsize=12)
plt.legend(loc='upper right')
plt.show()

# %%
print(gdf.head())  # Preview the first few rows
# Out:
#     Name  Camp        type_f                  geometry
# 0  Kule1  Kule  demand_point  POINT (34.25479 8.29992)
# 1  Kule2  Kule  demand_point  POINT (34.25602 8.28408)
# 2  Kule3  Kule  demand_point  POINT (34.24549 8.30417)
# 3  Kule4  Kule  demand_point  POINT (34.25934 8.29345)
# 4  Kule5  Kule  demand_point  POINT (34.23202 8.30456)
