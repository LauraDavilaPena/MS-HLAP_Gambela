# %% [markdown]
# # extracted file <br>

# %%
import geopandas as gpd
import contextily as ctx
import matplotlib.pyplot as plt

# Load the shapefile
shapefile_path = "eth_refugee_camps_unhcr_2019/Eth_refugee_camps_unhcr_2019.shp"
gdf = gpd.read_file(shapefile_path)

# Convert to Web Mercator (EPSG:3857) for basemap compatibility
gdf = gdf.to_crs(epsg=3857)

# Plot
fig, ax = plt.subplots(figsize=(10, 8))
gdf.plot(ax=ax, edgecolor="black", facecolor="none", linewidth=1)

# Add basemap
ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik)

# Show plot
plt.show()

# %%
gdf
# Out:
#     OBJECTID  FID_1        LocationTy     LocationGr       Name   Region  \
# 0          1     21      Refugee Camp  Refugee Place       Jewi  Gambela
# 1          2     30  Refugee Location  Refugee Place      Bonga  Gambela
# 2          3     22  Refugee Location  Refugee Place   Wanthowa  Gambela
# 3          4     23    Refugee Center  Refugee Place      Matar  Gambela
# 4          5     19      Refugee Camp  Refugee Place       Kule  Gambela
# ..       ...    ...               ...            ...        ...      ...
# 68        69     47      Refugee Camp  Refugee Place  Melkadida   Somali
# 69        70     50      Refugee Camp  Refugee Place       Kobe   Somali
# 70        71      6  Refugee Location  Refugee Place       Bure     Afar
# 71        72     33  Refugee Location  Refugee Place   Pochalla  Gambela
# 72        73     35  Refugee Location  Refugee Place     Moyale   Oromia
#
#                   Zone         Woreda   Latitude  Longitude  Active  \
# 0              Agnewak  Gambela Zuria   8.151990  34.703518     1.0
# 1              Agnewak  Gambela Zuria   8.183333  34.850000     0.0
# 2                Nuwer        Wantawo   8.272872  33.313000     0.0
# 3                Nuwer        Wantawo   8.352633  33.434975     1.0
# 4                Itang          Itang   8.283380  34.250920     1.0
# ..                 ...            ...        ...        ...     ...
# 68               Liban      Bokolmayo   4.522600  41.722600     1.0
# 69               Liban      Bokolmayo   4.481001  41.746900     1.0
# 70  Zone 1 (Awsi Rasu)         Elidar  12.601494  42.269217     1.0
# 71             Agnewak           Dima   7.172300  34.085100     1.0
# 72              Borena         Moyale   3.527000  39.056000     1.0
#
#                           geometry
# 0   POINT (3863263.747 910681.023)
# 1   POINT (3879570.384 914205.532)
# 2   POINT (3708468.475 924276.109)
# 3   POINT (3722046.996 933248.553)
# 4   POINT (3812879.624 925457.872)
# ..                             ...
# 68  POINT (4644640.504 504139.599)
# 69  POINT (4647345.611 499494.901)
# 70  POINT (4705493.075 1414323.44)
# 71  POINT (3795985.181 803724.346)
# 72   POINT (4347789.634 393044.65)
#
# [73 rows x 12 columns]

# %%
filtered_gdf = gdf[(gdf["Region"] == "Gambela") & (gdf["LocationTy"] == "Refugee Camp")]
filtered_gdf
# Out:
#     OBJECTID  FID_1    LocationTy     LocationGr       Name   Region     Zone  \
# 0          1     21  Refugee Camp  Refugee Place       Jewi  Gambela  Agnewak
# 4          5     19  Refugee Camp  Refugee Place       Kule  Gambela    Itang
# 5          6     20  Refugee Camp  Refugee Place   Tierkidi  Gambela    Itang
# 7          8     29  Refugee Camp  Refugee Place  Nguenyiel  Gambela    Itang
# 49        50     17  Refugee Camp  Refugee Place    Pugnido  Gambela  Agnewak
# 50        51     25  Refugee Camp  Refugee Place  Pugnido 2  Gambela  Agnewak
#
#            Woreda  Latitude  Longitude  Active                        geometry
# 0   Gambela Zuria  8.151990  34.703518     1.0  POINT (3863263.747 910681.023)
# 4           Itang  8.283380  34.250920     1.0  POINT (3812879.624 925457.872)
# 5           Itang  8.275170  34.275980     1.0  POINT (3815669.352 924534.386)
# 7           Itang  8.313006  34.328425     1.0  POINT (3821507.641 928790.366)
# 49            Gog  7.648250  34.268080     1.0  POINT (3814789.779 854072.366)
# 50            Gog  7.679180  34.247290     1.0  POINT (3812475.401 857546.217)

# %%
# Convert CRS for basemap compatibility
filtered_gdf = filtered_gdf.to_crs(epsg=3857)

# Plot
fig, ax = plt.subplots(figsize=(10, 8))
filtered_gdf.plot(ax=ax, color="red", facecolor="none", linewidth=1)

# Add a basemap
ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik)

plt.title("Refugee Camps in Gambela")
plt.show()
